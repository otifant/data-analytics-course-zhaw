# %% [markdown]
# # Week 2 Homework

# %% [markdown]
# ## Beach water quality dataset
#
# The dataset file in in your github repo, the file name is nic-beach-water-quality-automated-sensors-1.csv
#
# 🥦 <font color='red'>TODO</font>:
#
# * Create a new Jupyer Notebook
# 1. import numpy and pandas following the naming conventions
# 2. load the beach-water-quality-automated-sensors-1.csv dataset in a dataframe
# 3. how many rows of data does the dataset contain?
# 4. what were the 10 highest water temperatures?
# 5. what is the mean water temperature at Montrose Beach?
# 6. what are the names of the beaches in the dataset?
# 7. how many times was water temperature recorded above 26 degrees in 2016?
# 8. what can you say about the transducer depth data?
# 9. what can you say about the wave height data?
#
# ## The Exercises...
# ...are located in [this file](./homework2.2_water_quality.ipynb)

# %% [markdown]
# ## Explore your dataset
#
# 🥦  <font color='red'>TODO</font>:
#
# 1. Are there any missing data?
# 2. Do you see out of range data?
# 3. Do you see data type issues?

# %% [markdown]
# Dataset: [Soll/Ist Vergleich Abfahrts-/Ankunftszeiten SBB](https://data.sbb.ch/explore/dataset/ist-daten-sbb/table/?flg=de&dataChart=...%3D%3D)
#
# Here are some some older dataset with the same kind of data: https://opentransportdata.swiss/de/dataset/istdaten
#
# And here you get them as zip file for the years 2016 - 2023 (2016 and 2017 are incomplete): https://opentransportdata.swiss/de/ist-daten-archiv/
#
# ## Answers to the questions
# 1.
#     * Some columns don't have values for the departure and arrival time. And the funny thing about this is that this is not really dependend on the company. Sometimes, they just miss randomly.
#     * But for instance, if I want to find out whether buses have for all companies more delay than their trains, I think I have the data I need.
# 2. Yes, there is a lot of data which tells me nothing and I won't use like all ids and information about the line.
# 3. Depending on the company ("BETREIBER_ABK"), they don't use the same words for the same (e.g. TGV calls their trains "TGV", SBB calls them "Zug", and STI calls their buses "B"). Depending on what I want to find in these data, I must categorize them better.

# %% [markdown]
# ## Optional homework

# %% [markdown]
# ### 🌶️  Swiss Statistics
#
#
# > More safety for women - thanks to GPS?
# From one problem to the next. It is one issue that I feel very strongly about and at the same time makes me angry: violence against women. Let's note: According to the Federal Statistical Office, between 2009 and 2016, nearly 600 attempted and committed homicides were registered in the domestic field. That's an average of 75 per year. At the same time, we know that women are almost four times more likely to be victims than men, and the proportion of women killed is seven times higher. Not in the favelas of South America, nor in big cities in the USA, but in Switzerland - and among us. The fight against this is proving difficult; because contact points are overburdened or the police can only intervene when it is often already too late. In the latter case, a small device for victims of violent crime is soon to promise improvement. (Brun, 2023).
#
# **Reference**
#
# Brun, I.(2023). More safety for women - thanks to GPS? *Züri Briefing, #368*. https://tsri.ch/briefing

# %% [markdown]
# ### Source
#
#
# https://tsri.us9.list-manage.com/track/click?u=56ee24de7341c744008a13c9e&id=c787fcaab7&e=597574a247
#
# https://www.bfs.admin.ch/bfs/de/home/statistiken/kriminalitaet-strafrecht/polizei.gnpdetail.2021-0257.html

# %% [markdown]
# 🌶️  <font color='red'>TODO</font>:
#
# Explore some of the data files
# Load them into a pandas dataframe
#
# Hint: just the skip_rows parameter in the read_csv funciton to make sure you only read the relevant data
#
# for instance:
#
#
#
# <img src="https://nico.nexgate.ch/images/data_CH.png" width='80%' alt="excel" />

# %% [markdown]
# 🌶️  <font color='red'>TODO</font> (optional): In the notebook2.1.base.ipynb file, try to write the function to resolve quadratic equations.

# %% [markdown]
# 🌶️🌶️  <font color='red'>TODO</font>: Use the timeit magic function on the resolve_equation() function.
#
# Magic function documentation: https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %%
import pandas as pd

excel_file = "../data/lesson_2/hausliche_gewalt.xlsx"
sheet_name = '2009-2021'

columns = ['Year',
           'Total Men',
           'Total Women',
           'Partnership Men',
           'Partnership Women',
           'Ex Partnership Men',
           'Ex Partnership Women',
           'Adult-Child Relationship Men',
           'Adult-Child Relationship Women',
           'Other Relationship Men',
           'Other Relationship Women',
           ]

df = pd.read_excel(excel_file, sheet_name=sheet_name, header=4, names=columns, nrows=(18-6)+1)


# Print the resulting DataFrame
df.head()
df
# Out:
#     Year  Total Men  Total Women  Partnership Men  Partnership Women  \
# 0   2009       7476         1772             4435               1001
# 1   2010       6979         1756             4116                960
# 2   2011       6594         1614             3689                820
# 3   2012       6782         1765             3609                878
# 4   2013       7072         1881             3801                956
# 5   2014       6753         1856             3533                893
# 6   2015       7200         1995             3750                950
# 7   2016       7306         2272             3939               1123
# 8   2017       7059         2263             3867               1070
# 9   2018       7649         2416             4071               1208
# 10  2019       7893         2602             4300               1279
# 11  2020       8098         2781             4387               1418
# 12  2021       7717         2763             4154               1358
#
# ...

# %% [markdown]
# ### Visualization
#
# 🌶️  <font color='red'>TODO</font>:
#
# * Look for the reporting guidelines of your company or research lab
# * Look for the branding guidelines of your company (color palette with HEX color codes, communication style, types of imagery, ...)

# %% [markdown]
# # Reference documentation
#
# *   https://numpy.org/
# *   https://pandas.pydata.org/docs/
# *   https://pandas.pydata.org/docs/reference/series.html
# *   https://pandas.pydata.org/docs/reference/frame.html#
# *   https://matplotlib.org/
# *   https://mathim.com/static/chatprimer.html  (examples of LaTex to insert mathematical formulas in Jupyter notebooks)
#
# ## Python Data Science Handbook
#
# Relevant chapers:
#
# - Intro to pandas object
#  *   https://jakevdp.github.io/PythonDataScienceHandbook/03.01-introducing-pandas-objects.html
# - Data indexing and selection
#  * https://jakevdp.github.io/PythonDataScienceHandbook/03.02-data-indexing-and-selection.html
