# %% [markdown]
# # Week 3 Homework

# %% [markdown]
# ## Home prices dataset
#
# 🥦 <font color='red'>TODO</font>: Load and explore the home prices dataset
#
# ### Warm up
#
# * Copy the nic-home-prices.csv dataset to your laptop
# * Create a new Jupyer Notebook
# * import numpy and pandas following the naming conventions
# * load the nic-home-prices.csv dataset in a dataframe
#
# ```Python
# df = pd.read_csv('./nic-home-prices.csv)
# ```
#
#   * note: if needed, adjust the location of the data file
#
#
# * explore the data and find examples of:
#   * nominal variables
#   * ordinal variables
#   * discrete variables
#   * continuous variables
#
#   If you don't know what nominal vs ordinal etc. means, check this link: https://www.mygreatlearning.com/blog/types-of-data/
#
# * Create a boolean mask to identify houses in the dataset where the 'Sale Condition' is set to 'Abnorml'
#
# ```Python
# mark = ...
# df[mask]
# ```
#
#
#
# 🥦 <font color='red'>TODO</font>: Use a mask to filter data
#
# * Look at the 'Lot Frontage' data (Linear feet of street connected to property)
#  * what can you say about the data?
#  * would you rather replace the missing values by the mean or median? why?
#  * fill missing values using:
#
#  ```Python
# df['Lot Frontage'].fillna( ... )
# ```
#
#
#
#
# ### Outliers
#
# An outlier is a value in a data set that is very different from the other values.
#
# As you progress in your data science journey, it is important find ways to check if your data contains outliers (and eventually remove them if needed).
#
# <img src="https://nico.nexgate.ch/images/outlier.png" width='80%' alt="excel" />
# <center><u>Outliers</u> (source: medium.com)</center>
#
# In statistics, the standard deviation (σ) measures how numerically spread out the values are and the  z-score tells us how many standard deviations away a value is from the mean (μ). We use the following formula to calculate a z-score for a value X:
#
# z = (X – μ) / σ
#
#
#
#
# 🌶️🌶️  <font color='red'>TODO</font> (optional homework): Identify the outliers in the column "Gr Liv Area" (ground living area)
#
#  * option 1 (hard): define your own function to calculate the zscore and create a mark for your dataframe by checking if the zscore of the Ground living area is < -3 or > 3, finally extract the row from the dataset that are outliers for Gr Liv Area.
#  * option 2 (a bit easier): use the zscore function from the scipy.stats module
#  * option 3 (a bit easier): extract the column "Gr Liv Area", <pre>living_area = df['Gr Liv Area'])</pre>
# then import the seaborn package and visualize the outliers with a boxplot<pre>import seaborn as sns
# sns.boxplot(x=living_area)</pre>
#
# As a result, you should see something like:
#
# <img src="https://nico.nexgate.ch/images/boxplot.png" width='80%' alt="excel" />
# <center><u>Box Plot</u> (source: Gr Liv Area from house-prices)</center>
#
# 🌶️🌶️  <font color='red'>TODO</font> (optional homework): Finally, visualize the correlation between Ground Living Area ('Gr Liv Area') and house price ('SalePrice') and highlight the outliers on your chart
#
#
#  * STEP 1: Use the scatter plot visualization <i>plt.scatter</i>
#  * STEP 2: Use the parameter label,
#
#  ```Python
# plt.scatter( ...   ,label= ...)
# ```
#
#  * STEP 3: Add the outliers to your scatter chart, tip:
#     <pre>plt.scatter ( use a mask on your data , c= ... </pre>
#  * STEP 4: Use xlabel and ylabel to name your axes
#
# Your final result should look like this:
#
# <img src="https://nico.nexgate.ch/images/scatter.png" width='80%' alt="excel" />
#
# <center><u>Scatter plot</u> (source: Gr Liv Area and Price from house-prices)</center>

# %% [markdown]
# ## Progress for your class final project
#
# 🥦 <font color='red'>TODO</font>: Complete the first section of your project
#
# * If you have not done it already, upload your data files to your github student repo. (or upload a sample of data)
# * In your Github student repository, there is a "Project" folder where you can find a project template notebook.
#
# * Use this template to start working on your project.
# * Load your data<pre>pd.load_csv or pd.load_excel</pre>
# * use Jupyer Markup cells to document your project
# * use good variable names
# * look at the size of your data set
# ```Python
# shape
# info()
# ```
#
#  * describe your data (are there missing values, what are the data types, -...)
#
#  ```Python
# info()
# describe()
# df.column_xyz.value_counts()
# ```
#
# * describe the category of variables in your dataset (nominal, continuous, etc.)
# * aggregate and group data using
#
# ```Python
# df.groupby...
# ```
#
# * think about possible data visualizations
#
# ```Python
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt....
# ```

# %% [markdown]
# ### Explore Seaborn
#
# For your homework, you have used both Matplotlib and Seaborn.
# These are the most used packages for visualization in Python.
#
# Explore the seaborn package: https://seaborn.pydata.org/index.html
#
# Seaborn also comes with a lot of datasets that you can directly load.
#
# 🌶️ <font color='red'>TODO</font>: explore the seaborn datasets
#
# * Try the following code:
#
# ```Python
# import seaborn as sns
# sns.get_dataset_names()
# ```
#
# * Load and explore some of these datasets, try for instance:
#
# ```Python
# df_penguins = sns.load_dataset('penguins')
# ```
#
# * Try different visualizations from the seaborn library,
#
# ```Python
# sns.swarmplot( ... )
# ```
#
# Try to produce this swarm chart:
#
# <img src="https://nico.nexgate.ch/images/swarm.png" width='80%' alt="excel" />
#
# <center><u>Swarm plot</u> (source: sns penguins dataset)</center>
#
# ### Load data from the internet
#
# Many datasets are available on the internet and does not always make sense to copy the full dataset on your computer (some datasets are too large to be copied on a personal computer).
#
# Use the code below to load the official Corona virus stats from Switzerland:
#
# ```Python
# import pandas as pd
# import io
# import requests
# from matplotlib import pyplot as plt
# from datetime import datetime, date
#
# url = "https://raw.githubusercontent.com/openZH/covid_19/master/COVID19_Fallzahlen_CH_total.csv"
# s = requests.get(url).content
# df = pd.read_csv(io.StringIO(s.decode('utf-8')),parse_dates=['date'])
# df.info()
# ```
#
#
# 🌶️🌶️ <font color='red'>TODO</font>: Try to plot the historical evolution of positive cases for the canton of Zürich
#
# <img src="https://nico.nexgate.ch/images/covid_ZH.png" width='80%' alt="excel" />
#
# <center><u>Line plot</u> (source: sns penguins dataset)</center>

# %% [markdown]
# ## Optional reading: Python Data Science Handbook
#
# If you are unsure about these topics or if you want to see more examples the please read these chapters online:
#
# <font color='red'>TODO</font>: Aggregation and grouping: https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
#
# <font color='red'>TODO</font>: Simple line plots: https://jakevdp.github.io/PythonDataScienceHandbook/04.01-simple-line-plots.html
#
# <font color='red'>TODO</font>: Simple Scatter plots: https://jakevdp.github.io/PythonDataScienceHandbook/04.02-simple-scatter-plots.html
#
# <font color='red'>TODO</font>: Histograms (distribution charts) https://jakevdp.github.io/PythonDataScienceHandbook/04.05-histograms-and-binnings.html
#
# <font color='red'>TODO</font>: Customizing chart legends: https://jakevdp.github.io/PythonDataScienceHandbook/04.06-customizing-legends.html

# %% [markdown]
# # Partial homework solution

# %% [markdown]
# 2430 observations with potentially 80 features + 2 identifiers (Order, PID)
# The identifers do not have any influence on the dependent variable (SalePrice) and therefor will be removed form the training data set.
#
# There is a mix of continuous and categorical varibles which can be further split into 4 groups:
# - 23 nominal variables (e.g. 'MS Zoning' qualifies the purpose such as commercial vs. residential)
# - 23 ordinal variables (e.g. 'Garage Cond' from 'no garage', 'poor', ... to 'excellent')
# - 14 discrete variables (e.g. 'Fireplaces' counts the number of fireplaces)
# - 20 continuous variables (e.g. 'Gr Liv Area' which measures the living area in square feet)

# %%
import pandas as pd

df = pd.read_csv('https://bit.ly/3uiJFuH')

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    484  528275070           60        RL           NaN      8795   Pave
# 1   2586  535305120           20        RL          75.0     10170   Pave
# 2   2289  923228250          160        RM          21.0      2001   Pave
# 3    142  535152150           20        RL          70.0     10552   Pave
# 4   2042  903475060          190        RM          60.0     10120   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 3   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Bnk  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
df['Lot Frontage']
# Out:
# 0        NaN
# 1       75.0
# 2       21.0
# 3       70.0
# 4       60.0
#         ...
# 2425    60.0
# 2426    82.0
# 2427    80.0
# 2428    85.0
# 2429    75.0
# Name: Lot Frontage, Length: 2430, dtype: float64

# %% [markdown]
# ## Continuous variables

# %%
df_cont=df[['Lot Frontage', 'Lot Area', 'Mas Vnr Area', 'BsmtFin SF 1',
       'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF',
       '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area',
       'Garage Area', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch',
       '3Ssn Porch', 'Screen Porch', 'Pool Area','Misc Val','SalePrice']]

# %%
df_cont
# Out:
#       Lot Frontage  Lot Area  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# 0              NaN      8795           0.0         300.0           0.0
# 1             75.0     10170         522.0           0.0           0.0
# 2             21.0      2001          80.0           0.0           0.0
# 3             70.0     10552           0.0        1018.0           0.0
# 4             60.0     10120           0.0           0.0           0.0
# ...            ...       ...           ...           ...           ...
# 2425          60.0     10800           0.0        1200.0           0.0
# 2426          82.0     12464           0.0         732.0           0.0
# 2427          80.0     11584          96.0         315.0         110.0
# 2428          85.0     13400        1047.0         516.0         128.0
# 2429          75.0      9375           0.0         799.0           0.0
#
#       Bsmt Unf SF  Total Bsmt SF  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# ...

# %%
from matplotlib import pyplot as plt

# %%
fig,axes = plt.subplots(nrows=19,ncols=2,figsize=(16,100))
i=0    
for column in df_cont.columns[:-1]:
    ax=axes.flatten()[i]
    ax.scatter(df_cont[column],df_cont.SalePrice,c='C0',label=column)
    ax.legend()
    i+=1
    ax=axes.flatten()[i]
    ax.boxplot(df_cont[column],notch=True,vert=False)
    ax.get_yaxis().set_visible(False)
    i+=1

# %%
df_cont.isna().sum()  # checking for NaN values, Lot Frontage has a lot of missing values
# Out:
# Lot Frontage       420
# Lot Area             0
# Mas Vnr Area        20
# BsmtFin SF 1         1
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# 1st Flr SF           0
# 2nd Flr SF           0
# Low Qual Fin SF      0
# Gr Liv Area          0
# Garage Area          1
# Wood Deck SF         0
# Open Porch SF        0
# Enclosed Porch       0
# 3Ssn Porch           0
# Screen Porch         0
# Pool Area            0
# Misc Val             0
# SalePrice            0
# dtype: int64

# %%
# removing the 2 columns containing identifiers
print("shape before removing the columns ORder and PID ",df.shape) # (2430,82)
df.drop(['Order','PID'],axis=1,inplace=True) # step 1 in preprocessing
print("shape after removing the columns ORder and PID ",df.shape) # (2430,80)
# Out:
# shape before removing the columns ORder and PID  (2430, 82)
# shape after removing the columns ORder and PID  (2430, 80)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(df['Gr Liv Area'],df.SalePrice,label='normal')
liv_area_above_4000 = df['Gr Liv Area']>4000
plt.scatter(df[liv_area_above_4000]['Gr Liv Area'],
            df[liv_area_above_4000].SalePrice,
            c='C1',label='outliers')
plt.legend(loc='upper left')
plt.xlabel("Gr Liv Area")
plt.ylabel("Sale Price")
plt.show();

# %% [markdown]
# ### Using a boxplot to visualize outliers in a data Series

# %%
# when we extract the values from a Pandas dataframe's column, we obtain a Pandas' Series object
print("df['Gr Liv Area'] is of type ",type(df['Gr Liv Area']))
# Out:
# df['Gr Liv Area'] is of type  <class 'pandas.core.series.Series'>

# %%
# the seaborn package has a boxplot function which can use a Pandas Series as a parameter
import seaborn as sns
sns.boxplot(x=df['Gr Liv Area']);

# %% [markdown]
# ### Creating a mask (filter) to remove outliers.
#
# - step 1: calculate the z-scope for all values in the "Gr Liv Area" column
# - step 2: define a mark variable which will contain a Series of True/False values for each row of data by checking if the z-score if between -3 and +3. In order to do that, we can get the absolute value of the z-score (i.e. the z-score with the + or - sign), then compare it to <= 3.
# - step 3: apply this boolean condition to the dataframe

# %%
import numpy as np
from scipy import stats

# %%
# Step 1
z_scores = stats.zscore(df['Gr Liv Area'])
z_scores
# Out:
# 0       1.541890
# 1       0.169117
# 2      -0.804523
# 3       0.421095
# 4       0.802085
#           ...
# 2425   -0.586815
# 2426   -0.909346
# 2427    0.471490
# 2428   -0.816618
# 2429   -0.284442
# Name: Gr Liv Area, Length: 2430, dtype: float64

# %%
# Step 2
outliers_mask = np.abs(stats.zscore(df['Gr Liv Area'])) <= 3   
outliers_mask
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2425    True
# 2426    True
# 2427    True
# 2428    True
# 2429    True
# Name: Gr Liv Area, Length: 2430, dtype: bool

# %%
# Step 3, use the outliers' mark to filter data

# %%
df[outliers_mask]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0              60        RL           NaN      8795   Pave   NaN       IR1
# 1              20        RL          75.0     10170   Pave   NaN       Reg
# 2             160        RM          21.0      2001   Pave   NaN       Reg
# 3              20        RL          70.0     10552   Pave   NaN       IR1
# 4             190        RM          60.0     10120   Pave   NaN       IR1
# ...           ...       ...           ...       ...    ...   ...       ...
# 2425           90        RL          60.0     10800   Pave   NaN       Reg
# 2426           20        RL          82.0     12464   Pave   NaN       IR2
# 2427           60        RL          80.0     11584   Pave   NaN       Reg
# 2428           80        RL          85.0     13400   Pave   NaN       Reg
# 2429           20        RL          75.0      9375   Pave   NaN       Reg
#
# ...

# %% [markdown]
# ## 🌶️ How to calculate the z-score from scratch
#
# - step 1: calculate the standard deviation
# - step 2: calcualte the z-score

# %%
# Calculate the Standard Deviation 

# define a variable to hold the Pandas Series with all values for "Gr Liv Area"
Gr_Liv_Area_series = df['Gr Liv Area']

# calculate the mean average

mean_Gr_Liv_Area = sum(Gr_Liv_Area_series) / len(Gr_Liv_Area_series)

# calculate the differences and the sum of differences

Gr_Liv_Area_differences = [(value - mean_Gr_Liv_Area)**2 for value in Gr_Liv_Area_series]

sum_of_differences = sum(Gr_Liv_Area_differences)

std_Gr_Liv_Area = (sum_of_differences / (len(Gr_Liv_Area_series) - 1)) ** 0.5

print("The standard deviation for Gr Liv Area is ",std_Gr_Liv_Area)
# Out:
# The standard deviation for Gr Liv Area is  496.1782796909073

# %%
# we can verify that the std deviation calculation is correct by using the .describe() function on the dataframe 
df_cont.describe()[['Gr Liv Area']]
# Out:
#        Gr Liv Area
# count  2430.000000
# mean   1491.104938
# std     496.178280
# min     334.000000
# 25%    1120.000000
# 50%    1440.000000
# 75%    1740.000000
# max    5642.000000

# %%
# finally, we can calculate the z-score
zscores_Gr_Liv_Area = [(x - mean_Gr_Liv_Area) / std_Gr_Liv_Area for x in Gr_Liv_Area_series]

print(zscores_Gr_Liv_Area)
# Out:
# [1.5415730454885774, 0.16908249547049362, -0.8043579386833015, 0.4210080736676456, 0.8019195479017394, -0.6693258287696281, -0.32872244704707865, 0.761611455390195, 0.6245639408509444, -0.5887096437465394, -0.4859240078421015, 0.9450132763177217, 0.41294645516533673, -1.2699164071916385, 0.6467333917322937, -0.6713412333952054, -1.2638701933149068, -1.4996725345074409, 0.0380811948079746, 0.23962165736569618, 1.8600069763297775, -0.4113540366957445, 0.4008540274118734, 0.13885142608683537, 2.416258652989089, -0.43150808295151666, 1.2070158776427597, -0.33073785167265585, 0.06831226419163283, -0.23399842964494952, -0.2057827648868685, -1.2054234591731674, 1.5778503287489674, 0.7011493166228786, 0.695103102746147, -0.3952307996911268, -0.3045375915401521, -0.5786326206186534, 1.0155524382129242, -0.8748971005785041, -0.5222012911024914, -0.7922655109298382, -0.350891897928428, -0.3609689210563141, 0.4008540274118734, -0.014319325457033004, 0.39682321816071897, 0.8926127560527141, -0.39
# ...

# %%
# we can compare the results to the ones calculated with stats.zscore
z_scores
# Out:
# 0       1.541890
# 1       0.169117
# 2      -0.804523
# 3       0.421095
# 4       0.802085
#           ...
# 2425   -0.586815
# 2426   -0.909346
# 2427    0.471490
# 2428   -0.816618
# 2429   -0.284442
# Name: Gr Liv Area, Length: 2430, dtype: float64

# %% [markdown]
# ## Outliers removal

# %%
outliers_mask
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2425    True
# 2426    True
# 2427    True
# 2428    True
# 2429    True
# Name: Gr Liv Area, Length: 2430, dtype: bool

# %%
df_sans = df.loc[outliers_mask,:] # outliers removal

# %%
df.shape,df_sans.shape
# Out:
# ((2430, 80), (2414, 80))

# %%
# boxplot of the Ground Living area values after outliers' removal
sns.boxplot(x=df_sans['Gr Liv Area']);

# %% [markdown]
# ## Nominal variables
#
#
# <blockquote>Nominal Data is used to label variables without any order or quantitative value. The color of hair can be considered nominal data, as one color can’t be compared with another color.
#
# https://www.mygreatlearning.com/blog/types-of-data/
# </blockquote>

# %%
df_nomi = df[['MS SubClass','MS Zoning','Street','Alley','Land Contour','Lot Config',
             'Neighborhood','Condition 1','Condition 2','Bldg Type','House Style','Roof Style',
             'Roof Matl','Exterior 1st','Exterior 2nd','Mas Vnr Type','Foundation','Heating',
             'Central Air','Garage Type','Misc Feature','Sale Type','Sale Condition']].copy()

# %%
df_nomi
# Out:
#       MS SubClass MS Zoning Street Alley Land Contour Lot Config Neighborhood  \
# 0              60        RL   Pave   NaN          Lvl     Inside      Gilbert
# 1              20        RL   Pave   NaN          Lvl     Corner        NAmes
# 2             160        RM   Pave   NaN          Lvl     Inside      MeadowV
# 3              20        RL   Pave   NaN          Lvl     Inside        NAmes
# 4             190        RM   Pave   NaN          Bnk     Inside      OldTown
# ...           ...       ...    ...   ...          ...        ...          ...
# 2425           90        RL   Pave   NaN          Lvl     Inside      Edwards
# 2426           20        RL   Pave   NaN          Low     Corner      CollgCr
# 2427           60        RL   Pave   NaN          Lvl     Inside       NWAmes
# 2428           80        RL   Pave   NaN          Lvl     Inside        NAmes
# 2429           20        RL   Pave   NaN          Lvl     Corner      Edwards
#
# ...

# %%
df_nomi_short = df[['MS SubClass','MS Zoning','Street','Land Contour','Lot Config',
             'Neighborhood','Condition 1','Condition 2','Bldg Type','House Style','Roof Style',
             'Roof Matl','Exterior 1st','Exterior 2nd','Foundation','Heating',
             'Central Air','Garage Type','Sale Type','Sale Condition']].copy()

# %% [markdown]
# ## Ordinal data
#
# <blockquote>Unlike nominal data, ordinal data gives some kind of sequential order by their position on the scale. Examples: Economic status, customer satisfaction, education level, letter grades, etc
#
# https://www.mygreatlearning.com/blog/types-of-data/
# </blockquote>

# %%
ord_n_dis_vars = ['Lot Shape',  'Utilities',
       'Land Slope','Overall Qual',
       'Overall Cond', 'Year Built', 'Year Remod/Add', 
       'Exter Qual', 'Exter Cond', 'Bsmt Qual',
       'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 
       'BsmtFin Type 2','Heating QC','Electrical',  'Bsmt Full Bath',
       'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
       'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
       'Fireplaces', 'Fireplace Qu',  'Garage Yr Blt', 'Garage Finish',
       'Garage Cars', 'Garage Qual',
       'Garage Cond', 'Paved Drive', 'Pool QC',
       'Fence', 'Mo Sold', 'Yr Sold']
df[ord_n_dis_vars].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Data columns (total 37 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Lot Shape       2430 non-null   object
#  1   Utilities       2430 non-null   object
#  2   Land Slope      2430 non-null   object
#  3   Overall Qual    2430 non-null   int64
#  4   Overall Cond    2430 non-null   int64
#  5   Year Built      2430 non-null   int64
#  6   Year Remod/Add  2430 non-null   int64
#  7   Exter Qual      2430 non-null   object
#  8   Exter Cond      2430 non-null   object
#  9   Bsmt Qual       2359 non-null   object
#  10  Bsmt Cond       2359 non-null   object
#  11  Bsmt Exposure   2356 non-null   object
#  12  BsmtFin Type 1  2359 non-null   object
#  13  BsmtFin Type 2  2358 non-null   object
#  14  Heating QC      2430 non-null   object
#  15  Electrical      2429 non-null   object
#  16  Bsmt Full Bath  2428 non-null   float64
# ...

# %% [markdown]
# ## 🌶️ Feature engineering
#
# Feature engineering is a technique commonly used to prepare a dataset for machine learning. Let's look at two examples of feature engineering:
#
# - creating binary (0 or 1) variables from a zero-inflated variable
# - creating binary variables from qualitative variables

# %% [markdown]
# ### 🌶️ Dealing with zero-inflated variables

# %% [markdown]
# For some variables, there is a large number of rows with the value 0. These are commonly refered to as zero-inflated variables. Let's look at an example: the "Pool Area" column contains many rows = 0. Let's visualize the distribution of this variable with and without the zero values.

# %%
# with the zero values

plt.figure(figsize = (10,6))

sns.histplot(data = df, x = "Pool Area")

plt.show()

# %%
# let's create a mask to filter our the zero values
filter_Pool_Area = df['Pool Area']>0

# %%
# let's show the distribution without the zero values

plt.figure(figsize = (10,6))

sns.histplot(data = df[filter_Pool_Area], x = "Pool Area")

plt.show()

# %% [markdown]
# In this situation, we can create a new column to indicate if the property has a pool or not. This is called feature engineering because we create a new piece of data from existing data.

# %%
df['has_Pool_Area']=np.where(filter_Pool_Area,1,0)

# %%
df['has_Pool_Area']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2425    0
# 2426    0
# 2427    0
# 2428    0
# 2429    0
# Name: has_Pool_Area, Length: 2430, dtype: int64

# %%
df['has_Pool_Area'].value_counts()
# Out:
# 0    2418
# 1      12
# Name: has_Pool_Area, dtype: int64

# %% [markdown]
# ### Generating features (columns) from qualitative variables
#
# The dataset contains a column "Garage Type" which indicates if the property has a "Basement garage" or a "Car port" garange, etc. The description of garage types as string of characters if not easily used to train a machine learning model. In this case, we can automatically convert the "Garage Type" variable into multiple columns (1 column per garage type) and set the value 1 for the matching type and 0 otherwise.

# %%
df_augmented = pd.get_dummies(df,columns=['Garage Type'])

df_augmented
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0              60        RL           NaN      8795   Pave   NaN       IR1
# 1              20        RL          75.0     10170   Pave   NaN       Reg
# 2             160        RM          21.0      2001   Pave   NaN       Reg
# 3              20        RL          70.0     10552   Pave   NaN       IR1
# 4             190        RM          60.0     10120   Pave   NaN       IR1
# ...           ...       ...           ...       ...    ...   ...       ...
# 2425           90        RL          60.0     10800   Pave   NaN       Reg
# 2426           20        RL          82.0     12464   Pave   NaN       IR2
# 2427           60        RL          80.0     11584   Pave   NaN       Reg
# 2428           80        RL          85.0     13400   Pave   NaN       Reg
# 2429           20        RL          75.0      9375   Pave   NaN       Reg
#
# ...

# %%
# let's look at the 1st property, the column "Garage Type_BuiltIn" has the value 1 and all the other "Garage Type_xyz" columns have the value 0.

df_augmented.head(1).T
# Out:
#                         0
# MS SubClass            60
# MS Zoning              RL
# Lot Frontage          NaN
# Lot Area             8795
# Street               Pave
# ...                   ...
# Garage Type_Attchd      0
# Garage Type_Basment     0
# Garage Type_BuiltIn     1
# Garage Type_CarPort     0
# Garage Type_Detchd      0
#
# [86 rows x 1 columns]

# %% [markdown]
# ## 🌶️ Exploring seaborn datasets
#
# Here is an example of a seaborn dataset - the iris data - using in many machine learning courses.

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.set_style('whitegrid')

# %%
sns.histplot(iris['sepal_length'],kde=True)
# kde is the kernel density estimate. check seaborn histplot documentation for more details
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
# Many data analysis projects look into possible correlations between variables in a dataset.

# seaborn has a built-in funciton to visualize pairs of variables to help identify possible correlations.

sns.pairplot(iris);

# %%
# the same function can also be used to add a linear regression 

sns.pairplot(iris, kind='reg');
