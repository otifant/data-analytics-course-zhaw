# %% [markdown]
# Name
# Date

# %% [markdown]
# # Summary

# %% [markdown]
# Describe your project here.
# Describe in layman's terms your data so that a person with no expertise in your domain would understand the context and general purpose of your projecct.
#
# Explain how the data was created, its origin (e.g. user input, data colleccted from sensors on xyz, government census data, ...).
#
# You can also use pictures to the notebook.

# %% [markdown]
# # Imports

# %% [markdown]
# # Data acquisition

# %% [markdown]
# # EDI
# (exploratory data analysis)

# %% [markdown]
# # Data cleansing & data transformation

# %% [markdown]
# # Visualization

# %% [markdown]
# # Data storage (optional)

# %% [markdown]
# # References
